# %%
from pathlib import Path
import os
PROJECT_ROOT = Path.cwd().parents[1]
os.chdir(PROJECT_ROOT)
print("Working directory:", Path.cwd())
# Out:
# Working directory: /Users/macbook/Documents/EduVisionSeat/EduVisionSeat

# %%
# from src.notebook import test

# %%
# !pip install -U ultralytics

# %%
# %cd ultralytics
# Out:
# /Users/macbook/Documents/EduVisionSeat/EduVisionSeat/ultralytics

# %%
from ultralytics import YOLO
from glob import glob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from ultralytics.models import YOLO
#       2 from glob import glob
#
# ModuleNotFoundError: No module named 'ultralytics.models'

# %%
import ultralytics
print(ultralytics.__file__)
print(ultralytics.__path__)
# Out:
# None
# _NamespacePath(['/Users/macbook/Documents/EduVisionSeat/EduVisionSeat/ultralytics'])

# %%
# !pwd
# Out:
# /Users/macbook/Documents/EduVisionSeat/EduVisionSeat/ultralytics

# %%
# !pip install -e .
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.4.117-py3-none-any.whl.metadata (45 kB)
# Requirement already satisfied: filelock>=3.16.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (3.32.2)
# Requirement already satisfied: numpy>=1.23.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (2.4.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (3.11.0)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.7.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (5.0.0.93)
# Requirement already satisfied: pillow>=7.1.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (12.1.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (2.32.5)
# INFO: pip is looking at multiple versions of ultralytics to determine which version is compatible with other requirements. This could take a while.
#   Using cached ultralytics-8.4.116-py3-none-any.whl.metadata (45 kB)
#   Using cached ultralytics-8.4.115-py3-none-any.whl.metadata (45 kB)
#   Using cached ultralytics-8.4.114-py3-none-any.whl.metadata (45 kB)
#   Using cached ultralytics-8.4.113-py3-none-any.whl.metadata (45 kB)
#   Using cached ultralytics-8.4.112-py3-none-any.whl.metadata (45 kB)
#   Using cached ultralytics-8.4.111-py3-none-any.whl.metadata (45 kB)
#   Using cached ultralytics-8.4.110-py3-none-any.whl.metadata (45 kB)
# INFO: pip is still looking at multiple versions of ultralytics to determine which version is compatible with other requirements. This could take a while.
#   Using cached ultralytics-8.4.109-py3-none-any.whl.metadata (45 kB)
#   Using cached ultralytics-8.4.108-py3-none-any.whl.metadata (45 kB)
#   Using cached ultralytics-8.4.107-py3-none-any.whl.metadata (46 kB)
#   Using cached ultralytics-8.4.106-py3-none-any.whl.metadata (46 kB)
#   Using cached ultralytics-8.4.105-py3-none-any.whl.metadata (46 kB)
# INFO: This is taking longer than usual. You might need to provide the dependency resolver with stricter constraints to reduce runtime. See https://pip.pypa.io/warnings/backtracking for guidance. If you want to abort this run, press Ctrl + C.
#   Using cached ultralytics-8.4.104-py3-none-any.whl.metadata (45 kB)
#   Using cached ultralytics-8.4.103-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.102-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.101-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.100-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.99-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.98-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.97-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.96-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.95-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.94-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.93-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.92-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.91-py3-none-any.whl.metadata (42 kB)
#   Using cached ultralytics-8.4.90-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.89-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.88-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.87-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.86-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.85-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.84-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.83-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.82-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.81-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.80-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.79-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.78-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.77-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: scipy>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from ultralytics) (1.18.0)
#   Using cached ultralytics-8.4.76-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.75-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.74-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.73-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.72-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.71-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.70-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.69-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.68-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.67-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.66-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.65-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.64-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.63-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.62-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.61-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.60-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.59-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.58-py3-none-any.whl.metadata (41 kB)
#   Using cached ultralytics-8.4.57-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.56-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.55-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.54-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.53-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.52-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.51-py3-none-any.whl.metadata (36 kB)
#   Using cached ultralytics-8.4.50-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.49-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.48-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.47-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.46-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.45-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.43-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.42-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.41-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.40-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.39-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.38-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.37-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.36-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.34-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.33-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.32-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.31-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.30-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.29-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.28-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.27-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.26-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.25-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.24-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.23-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.22-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.21-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.20-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.19-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.18-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.17-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.16-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.15-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.14-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.13-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.12-py3-none-any.whl.metadata (38 kB)
#   Using cached ultralytics-8.4.11-py3-none-any.whl.metadata (38 kB)
#   Using cached ultralytics-8.4.10-py3-none-any.whl.metadata (38 kB)
#   Using cached ultralytics-8.4.9-py3-none-any.whl.metadata (38 kB)
#   Using cached ultralytics-8.4.8-py3-none-any.whl.metadata (38 kB)
#   Using cached ultralytics-8.4.7-py3-none-any.whl.metadata (38 kB)
#   Using cached ultralytics-8.4.6-py3-none-any.whl.metadata (38 kB)
#   Using cached ultralytics-8.4.5-py3-none-any.whl.metadata (38 kB)
#   Using cached ultralytics-8.4.4-py3-none-any.whl.metadata (39 kB)
#   Using cached ultralytics-8.4.3-py3-none-any.whl.metadata (38 kB)
#   Using cached ultralytics-8.4.2-py3-none-any.whl.metadata (36 kB)
#   Using cached ultralytics-8.4.1-py3-none-any.whl.metadata (36 kB)
#   Using cached ultralytics-8.4.0-py3-none-any.whl.metadata (36 kB)
#   Using cached ultralytics-8.3.253-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.252-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.251-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.250-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.249-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.248-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.247-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.246-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.245-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.244-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.243-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.242-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.241-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.240-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.239-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.238-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.237-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.236-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.235-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.234-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.233-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.232-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.231-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.230-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.229-py3-none-any.whl.metadata (37 kB)
# Collecting numpy<=2.3.4,>=1.23.0 (from ultralytics)
#   Using cached numpy-2.3.4-cp314-cp314-macosx_10_15_x86_64.whl.metadata (62 kB)
# Collecting matplotlib<=3.10.7,>=3.3.0 (from ultralytics)
#   Using cached matplotlib-3.10.7-cp314-cp314-macosx_10_13_x86_64.whl.metadata (11 kB)
# Collecting opencv-python<=4.12.0.88,>=4.6.0 (from ultralytics)
#   Using cached opencv-python-4.12.0.88.tar.gz (95.4 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pillow<=12.0.0,>=7.1.2 (from ultralytics)
#   Using cached pillow-12.0.0-cp314-cp314-macosx_10_15_x86_64.whl.metadata (8.8 kB)
# Collecting scipy<=1.16.3,>=1.4.1 (from ultralytics)
#   Using cached scipy-1.16.3-cp314-cp314-macosx_10_14_x86_64.whl.metadata (62 kB)
# Collecting ultralytics
#   Using cached ultralytics-8.3.228-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.227-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.226-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.225-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.224-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.223-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.222-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.221-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.220-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.219-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.218-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.217-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.216-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.215-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.214-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.213-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.212-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.211-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.210-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.209-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.208-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.207-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.206-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.205-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.204-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.203-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.202-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.201-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.200-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.199-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.198-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.197-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.196-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.195-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.194-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.193-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.192-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.191-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.190-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.189-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.188-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.187-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.186-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.185-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.184-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.183-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.182-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.181-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.180-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.179-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.178-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.177-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.176-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.175-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.174-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.173-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.172-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.171-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.170-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.169-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.168-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.167-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.166-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.165-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.164-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.163-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.162-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.161-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.160-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.159-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.158-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.157-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.156-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.155-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.154-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.153-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.152-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.151-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.150-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.149-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.148-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.147-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.146-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.145-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.144-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.143-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.142-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.141-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.140-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.139-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.138-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.137-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.136-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.135-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.134-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.133-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.132-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.131-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.130-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.129-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.128-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.127-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.126-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.125-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.124-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.123-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.122-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.121-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.120-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.119-py3-none-any.whl.metadata (37 kB)
#   Using cached ultralytics-8.3.118-py3-none-any.whl.metadata (37 kB)
# Collecting numpy<=2.1.1,>=1.23.0 (from ultralytics)
#   Using cached numpy-2.1.1.tar.gz (18.9 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory
#
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import sys
import ultralytics
print("CWD:", os.getcwd())
print("Python:", sys.executable)
print("Ultralytics:", ultralytics.__file__)
# Out:
# CWD: /Users/macbook/Documents/EduVisionSeat/EduVisionSeat/ultralytics
# Python: /usr/local/bin/python3.13
# Ultralytics: None

# %%
# !pwd
# Out:
# 3781.75s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# /Users/macbook/Documents/EduVisionSeat/EduVisionSeat/src/notebook

# %%
# !ls
# Out:
# 3826.85s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# data           detect.py      notebook.ipynb pose.ipynb     yolov8n.pt

# %%
INPUT_DIR = "data/images/input"
OUTPUT_DIR = "data/images/output"

os.makedirs(OUTPUT_DIR, exist_ok=True)

image_extensions = ('*.jpg', '*.jpeg', '*.png', '*.JPG', '*.JPEG', '*.PNG')
all_images = []
for ext in image_extensions:
    all_images.extend(glob(os.path.join(INPUT_DIR, ext)))

all_images.sort()

# %%
# Lấy 5 ảnh
target_images = all_images[:5]

if not target_images:
    print(f"Not found any images in the folder: {INPUT_DIR}")
else:
    model = YOLO("yolov8n.pt")
    
    print(f"Start analyzing image {len(target_images)}...")
    
    for img_path in target_images:
        # Chạy model
        results = model(img_path)
        
        # Lấy tên file gốc
        base_name = os.path.basename(img_path)
        # Tạo đường dẫn lưu mới
        save_path = os.path.join(OUTPUT_DIR, f"detected_{base_name}")
        
        # Lưu ảnh đã vẽ bounding box vào thư mục đích
        for result in results:
            result.save(filename=save_path)
            
        print(f" Đã xử lý và lưu: {save_path}")

print(" Hoàn thành phân tích 5 ảnh!")
